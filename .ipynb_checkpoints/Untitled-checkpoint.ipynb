# %% [markdown]
# # Top anime data 2024
# Our goal with this dataset is to predict whether the studio should spend money on production of an anime.
#     to achieve this we will look into the diverse features of the Top anime data 2025 dataset
#     https://www.kaggle.com/datasets/wiltheman/anime-data-set-for-ml

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('top_anime_data.csv')
df.head()
# Out:
#                       title_english            status  episodes  \
# 0                         One Piece  Currently Airing       0.0
# 1  Fullmetal Alchemist: Brotherhood   Finished Airing      64.0
# 2                   Hunter x Hunter   Finished Airing     148.0
# 3                       Steins;Gate   Finished Airing      24.0
# 4                   Attack on Titan   Finished Airing      25.0
#
#                            rating   rank  popularity  members  favorites  \
# 0       PG-13 - Teens 13 or older   52.0          17  2548930     239752
# 1  R - 17+ (violence & profanity)    2.0           3  3541474     234763
# 2       PG-13 - Teens 13 or older    8.0           8  3044411     221664
# 3       PG-13 - Teens 13 or older    3.0          14  2712158     196685
# 4  R - 17+ (violence & profanity)  117.0           1  4188784     181378
#
#    score  scored_by                                  genres  \
# 0   8.73  1449377.0              Action, Adventure, Fantasy
# 1   9.10  2228653.0       Action, Adventure, Drama, Fantasy
# 2   9.03  1889635.0              Action, Adventure, Fantasy
# 3   9.07  1470722.0                 Drama, Sci-Fi, Suspense
# 4   8.56  2952092.0  Action, Award Winning, Drama, Suspense
#
#                        themes demographics
# 0                         NaN      Shounen
# 1                    Military      Shounen
# 2                         NaN      Shounen
# 3  Psychological, Time Travel          NaN
# 4    Gore, Military, Survival      Shounen

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title_english  6700 non-null   object
#  1   status         10000 non-null  object
#  2   episodes       10000 non-null  float64
#  3   rating         9857 non-null   object
#  4   rank           8287 non-null   float64
#  5   popularity     10000 non-null  int64
#  6   members        10000 non-null  int64
#  7   favorites      10000 non-null  int64
#  8   score          9714 non-null   float64
#  9   scored_by      9714 non-null   float64
#  10  genres         9659 non-null   object
#  11  themes         6780 non-null   object
#  12  demographics   3122 non-null   object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 1015.8+ KB
